# %%
import pandas as pd

# %%
data = pd.read_csv("House Price India.csv")

# %%
data
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
new_data = data.loc[:, ['number of bedrooms', 'Price']]

# %%
new_data
# Out:
#        number of bedrooms    Price
# 0                       5  2380000
# 1                       4  1400000
# 2                       5  1200000
# 3                       4   838000
# 4                       3   805000
# ...                   ...      ...
# 14615                   2   221700
# 14616                   3   219200
# 14617                   2   209000
# 14618                   4   205000
# 14619                   3   146000
#
# [14620 rows x 2 columns]

# %%
Independent = pd.DataFrame(new_data["number of bedrooms"])

# %%
dependent = pd.DataFrame(new_data["Price"])

# %%
Independent.head(7)
# Out:
#    number of bedrooms
# 0                   5
# 1                   4
# 2                   5
# 3                   4
# 4                   3
# 5                   3
# 6                   5

# %%
dependent.head(7)
# Out:
#      Price
# 0  2380000
# 1  1400000
# 2  1200000
# 3   838000
# 4   805000
# 5   790000
# 6   785000

# %%
from sklearn.model_selection import train_test_split

# %%
Independent_train, Independent_test, dependent_train, dependent_test = train_test_split(Independent, dependent, test_size = 0.2, random_state = 77)

# %%
from sklearn.linear_model import LinearRegression

# %%
linearRegressor = LinearRegression()

# %%
linearRegressor.fit(Independent_train, dependent_train)
# Out:
# LinearRegression()

# %%
linearRegressor.intercept_
# Out:
# array([110582.54850694])

# %%
linearRegressor.coef_
# Out:
# array([[125742.78574551]])
